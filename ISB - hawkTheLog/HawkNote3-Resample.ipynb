# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %matplotlib inline

# %%
from sklearn.utils import resample

# %%
import time

# %%
raw_df = pd.read_csv('train_data.csv')

# %%
raw_df[raw_df.dissatisfaction==0].dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 322949 entries, 0 to 339599
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              322949 non-null  int64
#  1   gender                322949 non-null  object
#  2   order_time            322949 non-null  object
#  3   allot_time            322949 non-null  object
#  4   pickup_time           322949 non-null  object
#  5   delivered_time        322949 non-null  object
#  6   transport_id          322949 non-null  int64
#  7   first_mile_distance   322949 non-null  float64
#  8   last_mile_distance    322949 non-null  float64
#  9   alloted_orders        322949 non-null  float64
#  10  delivered_orders      322949 non-null  float64
#  11  customer_care_calls   322949 non-null  float64
#  12  membership            322949 non-null  object
#  13  product_importan      322949 non-null  object
#  14  lifetime_order_count  322949 non-null  float64
#  15  undelivered_orders    322949 non-null  float64
#  16  dissatisfaction       322949 non-null  int64
# dtypes: float64(7), int64(3), object(7)
# memory usage: 44.4+ MB

# %% [markdown]
# ## Resampling the data to make it balanced

# %%
no_diss = raw_df[raw_df.dissatisfaction==0].dropna()
diss = raw_df[raw_df.dissatisfaction==1]

# %%
down_no_diss = resample(no_diss,n_samples=2*len(diss),replace=False,random_state=42)

# %%
norm_df = pd.concat([diss,down_no_diss])
norm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12015 entries, 20 to 53441
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              12015 non-null  int64
#  1   gender                12015 non-null  object
#  2   order_time            12015 non-null  object
#  3   allot_time            12015 non-null  object
#  4   pickup_time           10131 non-null  object
#  5   delivered_time        8011 non-null   object
#  6   transport_id          12015 non-null  int64
#  7   first_mile_distance   12015 non-null  float64
#  8   last_mile_distance    12015 non-null  float64
#  9   alloted_orders        11517 non-null  float64
#  10  delivered_orders      11353 non-null  float64
#  11  customer_care_calls   12015 non-null  float64
#  12  membership            12015 non-null  object
#  13  product_importan      12015 non-null  object
#  14  lifetime_order_count  11977 non-null  float64
#  15  undelivered_orders    11353 non-null  float64
#  16  dissatisfaction       12015 non-null  int64
# dtypes: float64(7), int64(3), object(7)
# memory usage: 1.7+ MB

# %%
norm_df_copy = norm_df.copy()

# %%
norm_df['delivered_time'].fillna('31-12-9999 0:0',inplace=True)
norm_df['pickup_time'].fillna('31-12-8999 0:0',inplace=True)
#norm_df['lifetime_order_count'].fillna(norm_df['delivered_orders'].apply(lambda x: 8.32*x),inplace=True)
#norm_df['delivered_orders'].fillna(norm_df['lifetime_order_count'].apply(lambda x: x/8.32),inplace=True)

# %%
norm_df.dropna()['dissatisfaction'].value_counts()
# Out:
# 0    8010
# 1    3343
# Name: dissatisfaction, dtype: int64

# %%
3343*100/(3343+8010)
# Out:
# 29.445961419889016

# %%
norm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12015 entries, 20 to 53441
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              12015 non-null  int64
#  1   gender                12015 non-null  object
#  2   order_time            12015 non-null  object
#  3   allot_time            12015 non-null  object
#  4   pickup_time           12015 non-null  object
#  5   delivered_time        12015 non-null  object
#  6   transport_id          12015 non-null  int64
#  7   first_mile_distance   12015 non-null  float64
#  8   last_mile_distance    12015 non-null  float64
#  9   alloted_orders        11517 non-null  float64
#  10  delivered_orders      11353 non-null  float64
#  11  customer_care_calls   12015 non-null  float64
#  12  membership            12015 non-null  object
#  13  product_importan      12015 non-null  object
#  14  lifetime_order_count  11977 non-null  float64
#  15  undelivered_orders    11353 non-null  float64
#  16  dissatisfaction       12015 non-null  int64
# dtypes: float64(7), int64(3), object(7)
# memory usage: 1.7+ MB

# %%
norm_df_wna = norm_df.copy()

# %%
norm_df.dropna(inplace=True)

# %%
norm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11353 entries, 20 to 53441
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              11353 non-null  int64
#  1   gender                11353 non-null  object
#  2   order_time            11353 non-null  object
#  3   allot_time            11353 non-null  object
#  4   pickup_time           11353 non-null  object
#  5   delivered_time        11353 non-null  object
#  6   transport_id          11353 non-null  int64
#  7   first_mile_distance   11353 non-null  float64
#  8   last_mile_distance    11353 non-null  float64
#  9   alloted_orders        11353 non-null  float64
#  10  delivered_orders      11353 non-null  float64
#  11  customer_care_calls   11353 non-null  float64
#  12  membership            11353 non-null  object
#  13  product_importan      11353 non-null  object
#  14  lifetime_order_count  11353 non-null  float64
#  15  undelivered_orders    11353 non-null  float64
#  16  dissatisfaction       11353 non-null  int64
# dtypes: float64(7), int64(3), object(7)
# memory usage: 1.6+ MB

# %% [markdown]
# ## 1) Converting string to time, encoding necessary columns
# ## 2) Calculating time for delivery, pick-up & respective speeds

# %%
norm_df['order_time'] = norm_df['order_time'].apply(lambda x : time.strptime(x,'%d-%m-%Y %H:%M'))
norm_df['allot_time'] = norm_df['allot_time'].apply(lambda x : time.strptime(x,'%d-%m-%Y %H:%M'))
norm_df['pickup_time'] = norm_df['pickup_time'].apply(lambda x : time.strptime(x,'%d-%m-%Y %H:%M'))
norm_df['delivered_time'] = norm_df['delivered_time'].apply(lambda x : time.strptime(x,'%d-%m-%Y %H:%M'))

norm_df['time_to_pickup'] = norm_df.apply(lambda x : (time.mktime(x['pickup_time'])-time.mktime(x['allot_time']))/60,axis=1)
norm_df['time_to_delivery'] = norm_df.apply(lambda x : (time.mktime(x['delivered_time'])-time.mktime(x['pickup_time']))/60,axis=1)

norm_df['pickup_speed'] = (norm_df['first_mile_distance']*60)/(0.5+norm_df['time_to_pickup'])
norm_df['delivery_speed'] = (norm_df['last_mile_distance']*60)/(0.5+norm_df['time_to_delivery'])

norm_df['total_time'] = norm_df.apply(lambda x : (time.mktime(x['delivered_time'])-time.mktime(x['order_time']))/60,axis=1)

norm_df['prime_member'] = norm_df['membership'].apply(lambda x : 1 if x=='Prime' else 0)
norm_df['product_importance'] = norm_df['product_importan'].apply(lambda x : 0 if x=='low' else (1 if x=='other' else 2))

norm_df['gender_F'] = norm_df['gender'].apply(lambda x : 1 if x=='F' else 0)

# %%
norm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11353 entries, 20 to 53441
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              11353 non-null  int64
#  1   gender                11353 non-null  object
#  2   order_time            11353 non-null  object
#  3   allot_time            11353 non-null  object
#  4   pickup_time           11353 non-null  object
#  5   delivered_time        11353 non-null  object
#  6   transport_id          11353 non-null  int64
#  7   first_mile_distance   11353 non-null  float64
#  8   last_mile_distance    11353 non-null  float64
#  9   alloted_orders        11353 non-null  float64
#  10  delivered_orders      11353 non-null  float64
#  11  customer_care_calls   11353 non-null  float64
#  12  membership            11353 non-null  object
#  13  product_importan      11353 non-null  object
#  14  lifetime_order_count  11353 non-null  float64
#  15  undelivered_orders    11353 non-null  float64
#  16  dissatisfaction       11353 non-null  int64
#  17  time_to_pickup        11353 non-null  float64
#  18  time_to_delivery      11353 non-null  float64
#  19  pickup_speed          11353 non-null  float64
#  20  delivery_speed        11353 non-null  float64
#  21  total_time            11353 non-null  float64
#  22  prime_member          11353 non-null  int64
#  23  product_importance    11353 non-null  int64
#  24  gender_F              11353 non-null  int64
# dtypes: float64(12), int64(6), object(7)
# memory usage: 2.3+ MB

# %%
norm_df.head(10)
# Out:
#      order_id gender                          order_time  \
# 20    1003470      M  (2021, 1, 26, 3, 28, 0, 1, 26, -1)
# 68    1003518      F  (2021, 1, 26, 3, 45, 0, 1, 26, -1)
# 100   1003550      M  (2021, 1, 26, 3, 54, 0, 1, 26, -1)
# 163   1003613      F  (2021, 1, 26, 4, 11, 0, 1, 26, -1)
# 295   1003745      M  (2021, 1, 26, 4, 39, 0, 1, 26, -1)
# 317   1003767      M  (2021, 1, 26, 4, 43, 0, 1, 26, -1)
# 345   1003795      M  (2021, 1, 26, 4, 48, 0, 1, 26, -1)
# 445   1003895      F   (2021, 1, 26, 5, 3, 0, 1, 26, -1)
# 651   1004101      M  (2021, 1, 26, 5, 29, 0, 1, 26, -1)
# 774   1004224      F  (2021, 1, 26, 5, 45, 0, 1, 26, -1)
#
#                              allot_time                          pickup_time  \
# 20    (2021, 1, 26, 4, 9, 0, 1, 26, -1)   (2021, 1, 27, 3, 59, 0, 2, 27, -1)
# 68   (2021, 1, 26, 3, 45, 0, 1, 26, -1)  (8999, 12, 31, 0, 0, 0, 1, 365, -1)
# 100  (2021, 1, 26, 5, 29, 0, 1, 26, -1)  (8999, 12, 31, 0, 0, 0, 1, 365, -1)
# 163  (2021, 1, 26, 4, 12, 0, 1, 26, -1)  (8999, 12, 31, 0, 0, 0, 1, 365, -1)
# 295  (2021, 1, 26, 4, 39, 0, 1, 26, -1)  (8999, 12, 31, 0, 0, 0, 1, 365, -1)
# 317  (2021, 1, 26, 4, 44, 0, 1, 26, -1)   (2021, 1, 26, 4, 55, 0, 1, 26, -1)
# 345  (2021, 1, 26, 4, 49, 0, 1, 26, -1)    (2021, 1, 26, 5, 0, 0, 1, 26, -1)
# 445   (2021, 1, 26, 5, 3, 0, 1, 26, -1)   (2021, 1, 26, 5, 24, 0, 1, 26, -1)
# 651  (2021, 1, 26, 5, 37, 0, 1, 26, -1)  (8999, 12, 31, 0, 0, 0, 1, 365, -1)
# 774  (2021, 1, 26, 5, 45, 0, 1, 26, -1)   (2021, 1, 26, 5, 57, 0, 1, 26, -1)
#
#                           delivered_time  transport_id  first_mile_distance  \
# 20    (2021, 1, 27, 4, 15, 0, 2, 27, -1)         12885               28.438
# 68   (9999, 12, 31, 0, 0, 0, 4, 365, -1)         17557                8.617
# 100  (9999, 12, 31, 0, 0, 0, 4, 365, -1)          2391               29.217
# 163  (9999, 12, 31, 0, 0, 0, 4, 365, -1)         15229               21.287
# 295  (9999, 12, 31, 0, 0, 0, 4, 365, -1)          2373               16.053
# 317  (9999, 12, 31, 0, 0, 0, 4, 365, -1)          2049               20.333
# 345  (9999, 12, 31, 0, 0, 0, 4, 365, -1)           118                7.327
# 445  (9999, 12, 31, 0, 0, 0, 4, 365, -1)         13577               30.004
# 651  (9999, 12, 31, 0, 0, 0, 4, 365, -1)          8458               24.691
# 774  (9999, 12, 31, 0, 0, 0, 4, 365, -1)         16856               13.706
#
#      last_mile_distance  alloted_orders  ...  undelivered_orders  \
# 20               102.15            29.0  ...                 0.0
# 68                39.45            13.0  ...                 0.0
# 100               78.00           118.0  ...                 4.0
# 163                6.75            55.0  ...                 3.0
# 295               72.60           104.0  ...                 0.0
# 317               88.95            40.0  ...                 0.0
# 345                5.10            81.0  ...                 0.0
# 445               43.20            12.0  ...                 0.0
# 651               15.75             8.0  ...                 0.0
# 774               80.40            53.0  ...                 1.0
#
#      dissatisfaction time_to_pickup time_to_delivery  pickup_speed  \
# 20                 1   1.430000e+03     1.600000e+01  1.192786e+00
# 68                 1   3.670561e+09     5.259485e+08  1.408558e-07
# 100                1   3.670561e+09     5.259485e+08  4.775891e-07
# 163                1   3.670561e+09     5.259485e+08  3.479631e-07
# 295                1   3.670561e+09     5.259485e+08  2.624067e-07
# 317                1   1.100000e+01     4.196510e+09  1.060852e+02
# 345                1   1.100000e+01     4.196510e+09  3.822783e+01
# 445                1   2.100000e+01     4.196510e+09  8.373209e+01
# 651                1   3.670561e+09     5.259485e+08  4.036059e-07
# 774                1   1.200000e+01     4.196510e+09  6.578880e+01
#
#      delivery_speed    total_time  prime_member  product_importance  gender_F
# 20     3.714545e+02  1.487000e+03             0                   0         0
# 68     4.500441e-06  4.196510e+09             1                   2         1
# 100    8.898210e-06  4.196510e+09             0                   2         0
# 163    7.700374e-07  4.196510e+09             0                   0         1
# 295    8.282180e-06  4.196510e+09             1                   2         0
# 317    1.271771e-06  4.196510e+09             1                   0         0
# 345    7.291774e-08  4.196510e+09             0                   2         0
# 445    6.176562e-07  4.196510e+09             1                   2         1
# 651    1.796754e-06  4.196510e+09             0                   0         0
# 774    1.149527e-06  4.196510e+09             0                   2         1
#
# [10 rows x 25 columns]

# %%
#norm_df.to_csv('balanced_data_full.csv',index=False)

# %%
final_norm_df = norm_df.drop(['order_id','gender','product_importan','membership','order_time','allot_time',
                             'pickup_time','delivered_time','transport_id'],axis=1)

# %%
final_norm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11353 entries, 20 to 53441
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   first_mile_distance   11353 non-null  float64
#  1   last_mile_distance    11353 non-null  float64
#  2   alloted_orders        11353 non-null  float64
#  3   delivered_orders      11353 non-null  float64
#  4   customer_care_calls   11353 non-null  float64
#  5   lifetime_order_count  11353 non-null  float64
#  6   undelivered_orders    11353 non-null  float64
#  7   dissatisfaction       11353 non-null  int64
#  8   time_to_pickup        11353 non-null  float64
#  9   time_to_delivery      11353 non-null  float64
#  10  pickup_speed          11353 non-null  float64
#  11  delivery_speed        11353 non-null  float64
#  12  total_time            11353 non-null  float64
#  13  prime_member          11353 non-null  int64
#  14  product_importance    11353 non-null  int64
#  15  gender_F              11353 non-null  int64
# dtypes: float64(12), int64(4)
# memory usage: 1.5 MB

# %%
final_norm_df.head()
# Out:
#      first_mile_distance  last_mile_distance  alloted_orders  \
# 20                28.438              102.15            29.0
# 68                 8.617               39.45            13.0
# 100               29.217               78.00           118.0
# 163               21.287                6.75            55.0
# 295               16.053               72.60           104.0
#
#      delivered_orders  customer_care_calls  lifetime_order_count  \
# 20               29.0                  2.0                 449.0
# 68               13.0                  4.0                 168.0
# 100             114.0                  4.0                 860.0
# 163              52.0                  1.0                 256.0
# 295             104.0                  5.0                3282.0
#
#      undelivered_orders  dissatisfaction  time_to_pickup  time_to_delivery  \
# 20                  0.0                1    1.430000e+03              16.0
# 68                  0.0                1    3.670561e+09       525948480.0
# 100                 4.0                1    3.670561e+09       525948480.0
# 163                 3.0                1    3.670561e+09       525948480.0
# 295                 0.0                1    3.670561e+09       525948480.0
#
#      pickup_speed  delivery_speed    total_time  prime_member  \
# 20   1.192786e+00    3.714545e+02  1.487000e+03             0
# 68   1.408558e-07    4.500441e-06  4.196510e+09             1
# 100  4.775891e-07    8.898210e-06  4.196510e+09             0
# 163  3.479631e-07    7.700374e-07  4.196510e+09             0
# 295  2.624067e-07    8.282180e-06  4.196510e+09             1
#
#      product_importance  gender_F
# 20                    0         0
# 68                    2         1
# 100                   2         0
# 163                   0         1
# 295                   2         0

# %%
final_norm_df['dissatisfaction'].value_counts()
# Out:
# 0    8010
# 1    3343
# Name: dissatisfaction, dtype: int64

# %%
final_norm_df[final_norm_df['time_to_pickup']>0]['dissatisfaction'].value_counts()
# Out:
# 0    8009
# 1    3334
# Name: dissatisfaction, dtype: int64

# %%
sc_final_df = final_norm_df[final_norm_df['time_to_pickup']>0]

# %%
big_cols = ['first_mile_distance','last_mile_distance','pickup_speed','delivery_speed','total_time',
            'time_to_pickup','time_to_delivery']

for col in big_cols:
    sc_final_df[col] = np.log(1+sc_final_df[col])
# Out:
# /var/folders/s4/rbw51hr572v983ntn5czj87h0000gn/T/ipykernel_1904/3488937209.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sc_final_df[col] = np.log(1+sc_final_df[col])

# %%
sc_final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11343 entries, 20 to 53441
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   first_mile_distance   11343 non-null  float64
#  1   last_mile_distance    11343 non-null  float64
#  2   alloted_orders        11343 non-null  float64
#  3   delivered_orders      11343 non-null  float64
#  4   customer_care_calls   11343 non-null  float64
#  5   lifetime_order_count  11343 non-null  float64
#  6   undelivered_orders    11343 non-null  float64
#  7   dissatisfaction       11343 non-null  int64
#  8   time_to_pickup        11343 non-null  float64
#  9   time_to_delivery      11343 non-null  float64
#  10  pickup_speed          11343 non-null  float64
#  11  delivery_speed        11343 non-null  float64
#  12  total_time            11343 non-null  float64
#  13  prime_member          11343 non-null  int64
#  14  product_importance    11343 non-null  int64
#  15  gender_F              11343 non-null  int64
# dtypes: float64(12), int64(4)
# memory usage: 1.5 MB

# %%
sc_final_df.head(20)
# Out:
#       first_mile_distance  last_mile_distance  alloted_orders  \
# 20               3.382286            4.636184            29.0
# 68               2.263532            3.700067            13.0
# 100              3.408405            4.369448           118.0
# 163              3.104004            2.047693            55.0
# 295              2.836326            4.298645           104.0
# 317              3.060255            4.499254            40.0
# 345              2.119503            1.808289            81.0
# 445              3.434116            3.788725            12.0
# 651              3.246141            2.818398             8.0
# 774              2.688256            4.399375            53.0
# 858              3.020864            2.809403           124.0
# 900              3.653744            3.404525            99.0
# 954              3.023542            3.818811            11.0
# 1002             3.253664            3.988058           138.0
# 1125             3.162602            3.841601           154.0
# 1190             3.079706            3.768153            82.0
# 1256             3.896706            2.781920            17.0
# 1440             2.914034            4.237723             3.0
# 1466             1.013101            3.049273           157.0
# 1665             2.247706            4.269697           334.0
#
#       delivered_orders  customer_care_calls  lifetime_order_count  \
# 20                29.0                  2.0                 449.0
# 68                13.0                  4.0                 168.0
# 100              114.0                  4.0                 860.0
# 163               52.0                  1.0                 256.0
# 295              104.0                  5.0                3282.0
# 317               40.0                  4.0                2635.0
# 345               81.0                  2.0                2852.0
# 445               12.0                  3.0                 199.0
# 651                8.0                  3.0                  41.0
# 774               52.0                  5.0                1451.0
# 858              123.0                  4.0                3080.0
# 900               98.0                  4.0                 743.0
# 954               11.0                  2.0                 827.0
# 1002             133.0                  1.0                 312.0
# 1125             153.0                  1.0                1268.0
# 1190              82.0                  1.0                 620.0
# 1256              17.0                  5.0                 158.0
# 1440               3.0                  3.0                  10.0
# 1466             154.0                  1.0                 507.0
# 1665             333.0                  3.0                1328.0
#
#       undelivered_orders  dissatisfaction  time_to_pickup  time_to_delivery  \
# 20                   0.0                1        7.266129          2.833213
# 68                   0.0                1       22.023610         20.080714
# 100                  4.0                1       22.023610         20.080714
# 163                  3.0                1       22.023610         20.080714
# 295                  0.0                1       22.023610         20.080714
# 317                  0.0                1        2.484907         22.157519
# 345                  0.0                1        2.484907         22.157519
# 445                  0.0                1        3.091042         22.157519
# 651                  0.0                1       22.023610         20.080714
# 774                  1.0                1        2.564949         22.157519
# 858                  1.0                1       22.023610         20.080714
# 900                  1.0                1       22.023610         20.080714
# 954                  0.0                1       22.023610         20.080714
# 1002                 5.0                1       22.023610         20.080714
# 1125                 1.0                1       22.023610         20.080714
# 1190                 0.0                1       22.023610         20.080714
# 1256                 0.0                1       22.023610         20.080714
# 1440                 0.0                1        3.135494         22.157519
# 1466                 3.0                1       22.023610         20.080714
# 1665                 1.0                1       22.023610         20.080714
#
#       pickup_speed  delivery_speed  total_time  prime_member  \
# 20    7.851728e-01    5.920115e+00    7.305188             0
# 68    1.408558e-07    4.500431e-06   22.157519             1
# 100   4.775890e-07    8.898170e-06   22.157519             0
# 163   3.479631e-07    7.700371e-07   22.157519             0
# 295   2.624067e-07    8.282146e-06   22.157519             1
# 317   4.673625e+00    1.271770e-06   22.157519             1
# 345   3.669386e+00    7.291774e-08   22.157519             0
# 445   4.439494e+00    6.176560e-07   22.157519             1
# 651   4.036058e-07    1.796752e-06   22.157519             0
# 774   4.201535e+00    1.149526e-06   22.157519             0
# 858   3.188994e-07    1.779640e-06   22.157519             1
# 900   6.149303e-07    3.319711e-06   22.157519             1
# 954   3.197985e-07    5.082234e-06   22.157519             0
# 1002  4.067770e-07    6.040497e-06   22.157519             0
# 1125  3.699488e-07    5.202017e-06   22.157519             0
# 1190  3.392178e-07    4.825556e-06   22.157519             1
# 1256  7.885440e-07    1.728305e-06   22.157519             0
# 1440  3.860365e+00    9.758105e-07   22.157519             1
# 1466  2.867346e-08    2.292998e-06   22.157519             1
# 1665  1.383876e-07    8.042580e-06   22.157519             1
#
#       product_importance  gender_F
# 20                     0         0
# 68                     2         1
# 100                    2         0
# 163                    0         1
# 295                    2         0
# 317                    0         0
# 345                    2         0
# 445                    2         1
# 651                    0         0
# 774                    2         1
# 858                    2         1
# 900                    0         0
# 954                    2         1
# 1002                   1         1
# 1125                   1         1
# 1190                   0         0
# 1256                   0         0
# 1440                   2         0
# 1466                   0         0
# 1665                   0         0

# %%
X = sc_final_df.drop('dissatisfaction',axis=1)
y = sc_final_df['dissatisfaction']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
rf = RandomForestClassifier(random_state=42)

rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
print(classification_report(y_test,rf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1990
#            1       1.00      1.00      1.00       846
#
#     accuracy                           1.00      2836
#    macro avg       1.00      1.00      1.00      2836
# weighted avg       1.00      1.00      1.00      2836

# %%
#i give up
