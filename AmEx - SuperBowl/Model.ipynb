# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import KNNImputer
from xgboost import XGBClassifier
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, GRU, Dropout
import tensorflow as tf
from imblearn.ensemble import EasyEnsembleClassifier

# from imblearn.over_sampling import SMOTE
# from sklearn.utils import class_weight

# %%
data = pd.read_feather('./output/full_df_wNA_labelled')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458913 entries, 0 to 458912
# Columns: 189 entries, B_37 to Default_Flag
# dtypes: category(4), float64(184), int64(1)
# memory usage: 649.5 MB

# %%
null_cols = ['D_17','D_38', 'D_43', 'D_96', 'D_39', 'B_7', 'D_73', 'B_22', 'D_12', 'D_132', 
'D_114', 'D_80', 'D_97', 'R_8', 'B_26', 'D_110', 'R_7', 'D_11', 'D_95', 'D_105', 'D_48', 'D_141', 
'D_142', 'D_10', 'D_68', 'D_92', 'D_31', 'D_106', 'B_29', 'D_133', 'S_23', 'D_89', 'S_19', 'D_8', 'S_25', 'S_7', 'D_64', 'D_40', 'D_22']

# data_encoded = data.drop(null_cols,axis=1)

cat_columns = ['D_36','D_44']
data_encoded = pd.get_dummies(data,columns=cat_columns,drop_first=True)
data_encoded = data_encoded.astype({col: 'uint8' for col in data_encoded.select_dtypes('category').columns})

scaler = StandardScaler()
std_train_data = scaler.fit_transform(data_encoded.drop('Default_Flag',axis=1))
std_train_data = pd.DataFrame(std_train_data).fillna(1000)

# %%
# std_train_data = pd.DataFrame(std_train_data)
# imputer = KNNImputer(n_neighbors=100,weights='distance',add_indicator=True)
# std_train_data = imputer.fit_transform(std_train_data)

# %%
X = std_train_data
y = data_encoded['Default_Flag']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)
# X_train_rs, y_train_rs = SMOTE(n_jobs=-1,).fit_resample(X_train, y_train)

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestClassifier(random_state=42,class_weight="balanced",n_jobs=-1,bootstrap=True,)

rf.fit(X_train,y_train)
rf_preds = rf.predict(X_test)

print(classification_report(y_test, rf_preds))
print(confusion_matrix(y_test, rf_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91     85022
#            1       0.71      0.54      0.61      8625
#            2       0.43      0.34      0.38     11606
#            3       0.33      0.03      0.05      9476
#
#     accuracy                           0.80    114729
#    macro avg       0.58      0.47      0.49    114729
# weighted avg       0.75      0.80      0.76    114729
#
# [[83411   276  1192   143]
#  [ 2176  4650  1711    88]
#  [ 6213  1164  3974   255]
#  [ 6481   442  2316   237]]

# %% [markdown]
# ### Easy Ensemble Classifier

# %%
ee = EasyEnsembleClassifier(random_state=42,sampling_strategy={0:50000,1:10000,2:10000,3:10000},n_estimators=30,replacement=True,n_jobs=-1,)

ee.fit(X_train,y_train)
ee_preds = ee.predict(X_test)

print(classification_report(y_test, ee_preds))
print(confusion_matrix(y_test, ee_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93     85022
#            1       0.63      0.61      0.62      8625
#            2       0.42      0.35      0.38     11606
#            3       0.30      0.25      0.27      9476
#
#     accuracy                           0.80    114729
#    macro avg       0.56      0.54      0.55    114729
# weighted avg       0.79      0.80      0.79    114729
#
# [[80599   614  1466  2343]
#  [ 1071  5259  1689   606]
#  [ 3298  1752  4083  2473]
#  [ 3984   752  2399  2341]]

# %% [markdown]
# ### XGBoost

# %%
xgb = XGBClassifier(random_state=42, n_estimators=175, subsample=0.5, learning_rate=0.1, max_depth=7, gamma=0.25, colsample_bytree=0.5)

xgb.fit(X_train,y_train)
xgb_preds = xgb.predict(X_test)

print(classification_report(y_test, xgb_preds))
print(confusion_matrix(y_test, xgb_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93     85022
#            1       0.71      0.57      0.63      8625
#            2       0.42      0.49      0.45     11606
#            3       0.36      0.10      0.16      9476
#
#     accuracy                           0.82    114729
#    macro avg       0.60      0.53      0.54    114729
# weighted avg       0.79      0.82      0.80    114729
#
# [[82120   327  1880   695]
#  [ 1215  4883  2325   202]
#  [ 3864  1170  5677   895]
#  [ 4556   450  3482   988]]

# %% [markdown]
# ### Grid Search for Best parameters - XGB

# %%
param_grid = {
    "n_estimators" : [175],
    "max_depth": [7], # 3,5,9,10 done
    "learning_rate": [0.1], # 0.2,0.05,0.075 done
    "gamma": [0.25], #0, 1 done
    # "reg_lambda": [0, 1, 10],
    # "scale_pos_weight": [3, 5, 10],
    "subsample": [0.5],
    "colsample_bytree": [0.5] #0.8 done
}
# 0.81439, 0.81508, 0.81521

# %%
gridCV = GridSearchCV(XGBClassifier(random_state=42),param_grid, n_jobs=-1, cv=3, scoring="accuracy")

_ = gridCV.fit(X_train,y_train)

print('Best Score :',gridCV.best_score_)
print('Best parameters :',gridCV.best_params_)

# %% [markdown]
# ### Neural Network

# %%
model = Sequential()

model.add(tf.keras.Input(shape=(193,)))
model.add(Dense(512))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(4, activation='softmax'))

model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train,
          class_weight = {0:3 , 1:12, 2:10, 3:11},
          batch_size=2048,
          epochs=18,
          verbose=1,
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/18
# 169/169 [==============================] - 4s 22ms/step - loss: 24.7708 - accuracy: 0.5325 - val_loss: 1.2704 - val_accuracy: 0.7411
# Epoch 2/18
# 169/169 [==============================] - 3s 19ms/step - loss: 6.9944 - accuracy: 0.7276 - val_loss: 1.1547 - val_accuracy: 0.7411
# Epoch 3/18
# 169/169 [==============================] - 3s 20ms/step - loss: 6.6128 - accuracy: 0.7214 - val_loss: 0.9390 - val_accuracy: 0.7411
# Epoch 4/18
# 169/169 [==============================] - 3s 20ms/step - loss: 6.3912 - accuracy: 0.7186 - val_loss: 0.9073 - val_accuracy: 0.7411
# Epoch 5/18
# 169/169 [==============================] - 4s 21ms/step - loss: 6.2223 - accuracy: 0.7242 - val_loss: 0.8916 - val_accuracy: 0.7411
# Epoch 6/18
# 169/169 [==============================] - 4s 21ms/step - loss: 6.1206 - accuracy: 0.7251 - val_loss: 0.8361 - val_accuracy: 0.7411
# Epoch 7/18
# 169/169 [==============================] - 4s 22ms/step - loss: 6.0529 - accuracy: 0.7271 - val_loss: 0.8454 - val_accuracy: 0.7411
# Epoch 8/18
# 169/169 [==============================] - 4s 21ms/step - loss: 5.9852 - accuracy: 0.7286 - val_loss: 0.8139 - val_accuracy: 0.7411
# Epoch 9/18
# 169/169 [==============================] - 3s 21ms/step - loss: 5.9314 - accuracy: 0.7314 - val_loss: 0.8529 - val_accuracy: 0.7411
# Epoch 10/18
# 169/169 [==============================] - 4s 21ms/step - loss: 5.8865 - accuracy: 0.7345 - val_loss: 0.8928 - val_accuracy: 0.7411
# Epoch 11/18
# 169/169 [==============================] - 4s 22ms/step - loss: 5.8425 - accuracy: 0.7336 - val_loss: 0.8217 - val_accuracy: 0.7411
# Epoch 12/18
# 169/169 [==============================] - 4s 22ms/step - loss: 5.7878 - accuracy: 0.7338 - val_loss: 0.8087 - val_accuracy: 0.7411
# Epoch 13/18
# 169/169 [==============================] - 3s 21ms/step - loss: 5.7311 - accuracy: 0.7334 - val_loss: 0.8150 - val_accuracy: 0.7411
# Epoch 14/18
# 169/169 [==============================] - 3s 20ms/step - loss: 5.6665 - accuracy: 0.7300 - val_loss: 0.7669 - val_accuracy: 0.7411
# Epoch 15/18
# 169/169 [==============================] - 3s 20ms/step - loss: 5.6136 - accuracy: 0.6701 - val_loss: 0.7593 - val_accuracy: 0.6907
# Epoch 16/18
# 169/169 [==============================] - 3s 20ms/step - loss: 5.5626 - accuracy: 0.6295 - val_loss: 0.7521 - val_accuracy: 0.7239
# Epoch 17/18
# 169/169 [==============================] - 3s 20ms/step - loss: 5.4666 - accuracy: 0.6397 - val_loss: 0.8226 - val_accuracy: 0.7053
# Epoch 18/18
# 169/169 [==============================] - 3s 20ms/step - loss: 5.4084 - accuracy: 0.6471 - val_loss: 0.7037 - val_accuracy: 0.7307

# %%
tf_preds_prob = model.predict(X_test)
tf_preds = tf_preds_prob.argmax(axis=-1)
tf_preds[:5]
# Out:
# 3586/3586 [==============================] - 2s 516us/step
# array([0, 2, 2, 0, 0])

# %%
from sklearn.metrics import accuracy_score


print(classification_report(y_test,tf_preds))
print(confusion_matrix(y_test,tf_preds))
print("Accuracy :",accuracy_score(y_test, tf_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90     85022
#            1       0.00      0.00      0.00      8625
#            2       0.27      0.82      0.41     11606
#            3       0.00      0.00      0.00      9476
#
#     accuracy                           0.73    114729
#    macro avg       0.30      0.42      0.33    114729
# weighted avg       0.72      0.73      0.71    114729
#
# [[74330     0 10692     0]
#  [  832     0  7793     0]
#  [ 2101     0  9505     0]
#  [ 2483     0  6993     0]]
# Accuracy : 0.7307219621891587
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Grid Search - Neural Network

# %%
def build_model():    
    cv_tf = Sequential()
    cv_tf.add(tf.keras.Input(shape=(193,)))
    cv_tf.add(Dense(512))
    cv_tf.add(Dropout(0.3))
    cv_tf.add(Dense(256, activation='relu'))
    cv_tf.add(Dropout(0.2))
    cv_tf.add(Dense(128))
    cv_tf.add(Dropout(0.3))
    cv_tf.add(Dense(64, activation='relu'))
    cv_tf.add(Dropout(0.2))
    cv_tf.add(Dense(32, activation='relu'))
    cv_tf.add(Dropout(0.2))
    cv_tf.add(Dense(16, activation='relu'))
    cv_tf.add(Dropout(0.2))
    cv_tf.add(Dense(8, activation='relu'))
    cv_tf.add(Dropout(0.2))
    cv_tf.add(Dense(4, activation='softmax'))
    cv_tf.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
    return cv_tf

k_model = KerasClassifier(build_fn=build_model, verbose=0)

parameters = {'batch_size': [2048],
              'epochs': [17, 18, 19]
              }
grid_search = GridSearchCV(estimator = k_model,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 5,
                           verbose=0)
_ = grid_search.fit(X_train, y_train, verbose = 1)
# Out:
# /var/folders/s4/rbw51hr572v983ntn5czj87h0000gn/T/ipykernel_61098/363116421.py:22: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   k_model = KerasClassifier(build_fn=build_model, verbose=0)
# Epoch 1/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.7563 - accuracy: 0.6853
# Epoch 2/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5925 - accuracy: 0.7707
# Epoch 3/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5667 - accuracy: 0.7797
# Epoch 4/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5526 - accuracy: 0.7833
# Epoch 5/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5405 - accuracy: 0.7878
# Epoch 6/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5328 - accuracy: 0.7925
# Epoch 7/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5268 - accuracy: 0.7942
# Epoch 8/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5226 - accuracy: 0.7964
# Epoch 9/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5200 - accuracy: 0.7982
# Epoch 10/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5175 - accuracy: 0.7989
# Epoch 11/17
# 135/135 [==============================] - 2s 18ms/step - loss: 0.5166 - accuracy: 0.7987
# Epoch 12/17
# 135/135 [==============================] - 2s 18ms/step - loss: 0.5138 - accuracy: 0.7993
# Epoch 13/17
# 135/135 [==============================] - 2s 18ms/step - loss: 0.5120 - accuracy: 0.7999
# Epoch 14/17
# 135/135 [==============================] - 2s 18ms/step - loss: 0.5097 - accuracy: 0.8006
# Epoch 15/17
# 135/135 [==============================] - 2s 18ms/step - loss: 0.5089 - accuracy: 0.8010
# Epoch 16/17
# 135/135 [==============================] - 2s 18ms/step - loss: 0.5082 - accuracy: 0.8010
# Epoch 17/17
# 135/135 [==============================] - 2s 18ms/step - loss: 0.5069 - accuracy: 0.8016
# 2152/2152 [==============================] - 1s 539us/step
# Epoch 1/17
# 135/135 [==============================] - 3s 18ms/step - loss: 0.6747 - accuracy: 0.7287
# Epoch 2/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5840 - accuracy: 0.7617
# Epoch 3/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5545 - accuracy: 0.7799
# Epoch 4/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5388 - accuracy: 0.7858
# Epoch 5/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5301 - accuracy: 0.7885
# Epoch 6/17
# 135/135 [==============================] - 2s 18ms/step - loss: 0.5270 - accuracy: 0.7895
# Epoch 7/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5230 - accuracy: 0.7915
# Epoch 8/17
# 135/135 [==============================] - 2s 18ms/step - loss: 0.5195 - accuracy: 0.7921
# Epoch 9/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5150 - accuracy: 0.7950
# Epoch 10/17
# 135/135 [==============================] - 2s 18ms/step - loss: 0.5115 - accuracy: 0.7984
# Epoch 11/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5083 - accuracy: 0.8003
# Epoch 12/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5065 - accuracy: 0.8011
# Epoch 13/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5058 - accuracy: 0.8019
# Epoch 14/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5033 - accuracy: 0.8022
# Epoch 15/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5031 - accuracy: 0.8027
# Epoch 16/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5013 - accuracy: 0.8025
# Epoch 17/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5003 - accuracy: 0.8033
# 2152/2152 [==============================] - 1s 466us/step
# Epoch 1/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.6766 - accuracy: 0.7351
# Epoch 2/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5651 - accuracy: 0.7752
# Epoch 3/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5458 - accuracy: 0.7880
# Epoch 4/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5363 - accuracy: 0.7934
# Epoch 5/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5296 - accuracy: 0.7961
# Epoch 6/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5254 - accuracy: 0.7978
# Epoch 7/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5216 - accuracy: 0.7985
# Epoch 8/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5187 - accuracy: 0.7999
# Epoch 9/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5152 - accuracy: 0.8012
# Epoch 10/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5124 - accuracy: 0.8013
# Epoch 11/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5099 - accuracy: 0.8023
# Epoch 12/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5071 - accuracy: 0.8027
# Epoch 13/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5062 - accuracy: 0.8028
# Epoch 14/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5042 - accuracy: 0.8028
# Epoch 15/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5043 - accuracy: 0.8030
# Epoch 16/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5022 - accuracy: 0.8037
# Epoch 17/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5017 - accuracy: 0.8032
# 2152/2152 [==============================] - 1s 495us/step
# Epoch 1/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.6601 - accuracy: 0.7305
# Epoch 2/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5609 - accuracy: 0.7832
# Epoch 3/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5412 - accuracy: 0.7943
# Epoch 4/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5303 - accuracy: 0.7981
# Epoch 5/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5247 - accuracy: 0.7996
# Epoch 6/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5198 - accuracy: 0.8011
# Epoch 7/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5143 - accuracy: 0.8019
# Epoch 8/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5124 - accuracy: 0.8019
# Epoch 9/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5118 - accuracy: 0.8019
# Epoch 10/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5096 - accuracy: 0.8025
# Epoch 11/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5060 - accuracy: 0.8026
# Epoch 12/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5047 - accuracy: 0.8027
# Epoch 13/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5037 - accuracy: 0.8027
# Epoch 14/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5027 - accuracy: 0.8028
# Epoch 15/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5024 - accuracy: 0.8025
# Epoch 16/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5011 - accuracy: 0.8029
# Epoch 17/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.4994 - accuracy: 0.8035
# 2152/2152 [==============================] - 1s 503us/step
# Epoch 1/17
# 135/135 [==============================] - 3s 19ms/step - loss: 0.8011 - accuracy: 0.7139
# Epoch 2/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5823 - accuracy: 0.7798
# Epoch 3/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5542 - accuracy: 0.7913
# Epoch 4/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5407 - accuracy: 0.7945
# Epoch 5/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5357 - accuracy: 0.7961
# Epoch 6/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5307 - accuracy: 0.7969
# Epoch 7/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5268 - accuracy: 0.7981
# Epoch 8/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5240 - accuracy: 0.7980
# Epoch 9/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5213 - accuracy: 0.7987
# Epoch 10/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5192 - accuracy: 0.7993
# Epoch 11/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5160 - accuracy: 0.8005
# Epoch 12/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5141 - accuracy: 0.8013
# Epoch 13/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5105 - accuracy: 0.8026
# Epoch 14/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5100 - accuracy: 0.8027
# Epoch 15/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5083 - accuracy: 0.8027
# Epoch 16/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5069 - accuracy: 0.8036
# Epoch 17/17
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5053 - accuracy: 0.8035
# 2152/2152 [==============================] - 1s 491us/step
# Epoch 1/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.8157 - accuracy: 0.7047
# Epoch 2/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.6878 - accuracy: 0.7781
# Epoch 3/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.6581 - accuracy: 0.7865
# Epoch 4/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.6320 - accuracy: 0.7918
# Epoch 5/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.6009 - accuracy: 0.7926
# Epoch 6/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5444 - accuracy: 0.7949
# Epoch 7/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5357 - accuracy: 0.7965
# Epoch 8/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5314 - accuracy: 0.7974
# Epoch 9/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5283 - accuracy: 0.7989
# Epoch 10/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5244 - accuracy: 0.7989
# Epoch 11/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5233 - accuracy: 0.7997
# Epoch 12/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5205 - accuracy: 0.7994
# Epoch 13/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5183 - accuracy: 0.8007
# Epoch 14/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5171 - accuracy: 0.8005
# Epoch 15/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5161 - accuracy: 0.8003
# Epoch 16/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5150 - accuracy: 0.8007
# Epoch 17/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5131 - accuracy: 0.8007
# Epoch 18/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5137 - accuracy: 0.8008
# 2152/2152 [==============================] - 1s 503us/step
# Epoch 1/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.6486 - accuracy: 0.7392
# Epoch 2/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5632 - accuracy: 0.7769
# Epoch 3/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5396 - accuracy: 0.7875
# Epoch 4/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5301 - accuracy: 0.7892
# Epoch 5/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5230 - accuracy: 0.7914
# Epoch 6/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5192 - accuracy: 0.7930
# Epoch 7/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5168 - accuracy: 0.7959
# Epoch 8/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5129 - accuracy: 0.7967
# Epoch 9/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5112 - accuracy: 0.7974
# Epoch 10/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5098 - accuracy: 0.7985
# Epoch 11/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5091 - accuracy: 0.7986
# Epoch 12/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5072 - accuracy: 0.8002
# Epoch 13/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5056 - accuracy: 0.7997
# Epoch 14/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5040 - accuracy: 0.8015
# Epoch 15/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5029 - accuracy: 0.8017
# Epoch 16/18
# 135/135 [==============================] - 3s 22ms/step - loss: 0.5029 - accuracy: 0.8025
# Epoch 17/18
# 135/135 [==============================] - 3s 22ms/step - loss: 0.5012 - accuracy: 0.8026
# Epoch 18/18
# 135/135 [==============================] - 3s 22ms/step - loss: 0.5013 - accuracy: 0.8033
# 2152/2152 [==============================] - 1s 511us/step
# Epoch 1/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.7701 - accuracy: 0.6839
# Epoch 2/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5974 - accuracy: 0.7701
# Epoch 3/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5640 - accuracy: 0.7817
# Epoch 4/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5464 - accuracy: 0.7858
# Epoch 5/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5373 - accuracy: 0.7894
# Epoch 6/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5287 - accuracy: 0.7932
# Epoch 7/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5240 - accuracy: 0.7941
# Epoch 8/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5197 - accuracy: 0.7963
# Epoch 9/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5184 - accuracy: 0.7963
# Epoch 10/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5141 - accuracy: 0.7969
# Epoch 11/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5118 - accuracy: 0.7989
# Epoch 12/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5113 - accuracy: 0.8001
# Epoch 13/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5083 - accuracy: 0.8016
# Epoch 14/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5070 - accuracy: 0.8018
# Epoch 15/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5048 - accuracy: 0.8031
# Epoch 16/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5043 - accuracy: 0.8034
# Epoch 17/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5026 - accuracy: 0.8032
# Epoch 18/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5015 - accuracy: 0.8039
# 2152/2152 [==============================] - 1s 508us/step
# Epoch 1/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.8155 - accuracy: 0.6370
# Epoch 2/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5767 - accuracy: 0.7721
# Epoch 3/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5537 - accuracy: 0.7801
# Epoch 4/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5413 - accuracy: 0.7883
# Epoch 5/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5335 - accuracy: 0.7941
# Epoch 6/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5258 - accuracy: 0.7973
# Epoch 7/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5209 - accuracy: 0.7993
# Epoch 8/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5180 - accuracy: 0.8003
# Epoch 9/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5147 - accuracy: 0.8013
# Epoch 10/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5115 - accuracy: 0.8024
# Epoch 11/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5101 - accuracy: 0.8023
# Epoch 12/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5088 - accuracy: 0.8026
# Epoch 13/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5062 - accuracy: 0.8035
# Epoch 14/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5049 - accuracy: 0.8026
# Epoch 15/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5040 - accuracy: 0.8034
# Epoch 16/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5016 - accuracy: 0.8035
# Epoch 17/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5019 - accuracy: 0.8031
# Epoch 18/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5010 - accuracy: 0.8041
# 2152/2152 [==============================] - 1s 523us/step
# Epoch 1/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.8479 - accuracy: 0.6118
# Epoch 2/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5967 - accuracy: 0.7588
# Epoch 3/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5588 - accuracy: 0.7840
# Epoch 4/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5403 - accuracy: 0.7926
# Epoch 5/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5257 - accuracy: 0.7983
# Epoch 6/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5190 - accuracy: 0.8002
# Epoch 7/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5159 - accuracy: 0.8007
# Epoch 8/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5130 - accuracy: 0.8014
# Epoch 9/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5102 - accuracy: 0.8017
# Epoch 10/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5073 - accuracy: 0.8015
# Epoch 11/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5069 - accuracy: 0.8021
# Epoch 12/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5062 - accuracy: 0.8018
# Epoch 13/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5056 - accuracy: 0.8021
# Epoch 14/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5039 - accuracy: 0.8025
# Epoch 15/18
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5021 - accuracy: 0.8028
# Epoch 16/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5004 - accuracy: 0.8035
# Epoch 17/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.4995 - accuracy: 0.8035
# Epoch 18/18
# 135/135 [==============================] - 3s 20ms/step - loss: 0.4985 - accuracy: 0.8043
# 2152/2152 [==============================] - 1s 543us/step
# Epoch 1/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.6242 - accuracy: 0.7532
# Epoch 2/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5531 - accuracy: 0.7794
# Epoch 3/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5382 - accuracy: 0.7880
# Epoch 4/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5301 - accuracy: 0.7915
# Epoch 5/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5239 - accuracy: 0.7923
# Epoch 6/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5196 - accuracy: 0.7935
# Epoch 7/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5163 - accuracy: 0.7949
# Epoch 8/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5129 - accuracy: 0.7967
# Epoch 9/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5113 - accuracy: 0.7970
# Epoch 10/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5105 - accuracy: 0.7973
# Epoch 11/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5085 - accuracy: 0.7983
# Epoch 12/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5080 - accuracy: 0.7985
# Epoch 13/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5069 - accuracy: 0.7996
# Epoch 14/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5056 - accuracy: 0.7997
# Epoch 15/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5047 - accuracy: 0.8003
# Epoch 16/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5031 - accuracy: 0.8014
# Epoch 17/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5028 - accuracy: 0.8015
# Epoch 18/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5022 - accuracy: 0.8019
# Epoch 19/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5019 - accuracy: 0.8021
# 2152/2152 [==============================] - 1s 516us/step
# Epoch 1/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.7912 - accuracy: 0.6599
# Epoch 2/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.6000 - accuracy: 0.7619
# Epoch 3/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5721 - accuracy: 0.7760
# Epoch 4/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5500 - accuracy: 0.7858
# Epoch 5/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5392 - accuracy: 0.7888
# Epoch 6/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5320 - accuracy: 0.7931
# Epoch 7/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5273 - accuracy: 0.7956
# Epoch 8/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5238 - accuracy: 0.7969
# Epoch 9/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5191 - accuracy: 0.7985
# Epoch 10/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5177 - accuracy: 0.7992
# Epoch 11/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5152 - accuracy: 0.8000
# Epoch 12/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5132 - accuracy: 0.8003
# Epoch 13/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5110 - accuracy: 0.8009
# Epoch 14/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5116 - accuracy: 0.8007
# Epoch 15/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5091 - accuracy: 0.8011
# Epoch 16/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5084 - accuracy: 0.8014
# Epoch 17/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5078 - accuracy: 0.8018
# Epoch 18/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5062 - accuracy: 0.8016
# Epoch 19/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5053 - accuracy: 0.8023
# 2152/2152 [==============================] - 1s 622us/step
# Epoch 1/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.7264 - accuracy: 0.7290
# Epoch 2/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5821 - accuracy: 0.7734
# Epoch 3/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5548 - accuracy: 0.7822
# Epoch 4/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5415 - accuracy: 0.7879
# Epoch 5/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5326 - accuracy: 0.7919
# Epoch 6/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5266 - accuracy: 0.7950
# Epoch 7/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5223 - accuracy: 0.7971
# Epoch 8/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5191 - accuracy: 0.7978
# Epoch 9/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5162 - accuracy: 0.7993
# Epoch 10/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5141 - accuracy: 0.7995
# Epoch 11/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5122 - accuracy: 0.8000
# Epoch 12/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5104 - accuracy: 0.8001
# Epoch 13/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5083 - accuracy: 0.8008
# Epoch 14/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5068 - accuracy: 0.8017
# Epoch 15/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5062 - accuracy: 0.8013
# Epoch 16/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5060 - accuracy: 0.8021
# Epoch 17/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5042 - accuracy: 0.8020
# Epoch 18/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5036 - accuracy: 0.8014
# Epoch 19/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5025 - accuracy: 0.8016
# 2152/2152 [==============================] - 1s 557us/step
# Epoch 1/19
# 135/135 [==============================] - 3s 18ms/step - loss: 0.7685 - accuracy: 0.6821
# Epoch 2/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.6078 - accuracy: 0.7711
# Epoch 3/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5743 - accuracy: 0.7827
# Epoch 4/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5536 - accuracy: 0.7914
# Epoch 5/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5381 - accuracy: 0.7946
# Epoch 6/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5303 - accuracy: 0.7971
# Epoch 7/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5254 - accuracy: 0.7986
# Epoch 8/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5223 - accuracy: 0.7986
# Epoch 9/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5190 - accuracy: 0.7990
# Epoch 10/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5173 - accuracy: 0.7998
# Epoch 11/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5148 - accuracy: 0.8000
# Epoch 12/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5137 - accuracy: 0.8008
# Epoch 13/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5115 - accuracy: 0.8007
# Epoch 14/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5109 - accuracy: 0.8008
# Epoch 15/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5084 - accuracy: 0.8014
# Epoch 16/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5079 - accuracy: 0.8013
# Epoch 17/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5063 - accuracy: 0.8015
# Epoch 18/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5063 - accuracy: 0.8024
# Epoch 19/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5046 - accuracy: 0.8023
# 2152/2152 [==============================] - 1s 508us/step
# Epoch 1/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.7516 - accuracy: 0.7110
# Epoch 2/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5953 - accuracy: 0.7703
# Epoch 3/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5653 - accuracy: 0.7803
# Epoch 4/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5485 - accuracy: 0.7930
# Epoch 5/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5380 - accuracy: 0.7971
# Epoch 6/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5314 - accuracy: 0.7984
# Epoch 7/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5278 - accuracy: 0.7979
# Epoch 8/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5211 - accuracy: 0.7989
# Epoch 9/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5159 - accuracy: 0.7998
# Epoch 10/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5132 - accuracy: 0.7998
# Epoch 11/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5117 - accuracy: 0.8005
# Epoch 12/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5091 - accuracy: 0.8005
# Epoch 13/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5079 - accuracy: 0.8004
# Epoch 14/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5075 - accuracy: 0.8014
# Epoch 15/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5067 - accuracy: 0.8019
# Epoch 16/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5054 - accuracy: 0.8019
# Epoch 17/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5041 - accuracy: 0.8022
# Epoch 18/19
# 135/135 [==============================] - 3s 19ms/step - loss: 0.5036 - accuracy: 0.8027
# Epoch 19/19
# 135/135 [==============================] - 3s 20ms/step - loss: 0.5015 - accuracy: 0.8027
# 2152/2152 [==============================] - 1s 586us/step
# Epoch 1/18
# 169/169 [==============================] - 4s 19ms/step - loss: 0.6543 - accuracy: 0.7404
# Epoch 2/18
# 169/169 [==============================] - 3s 19ms/step - loss: 0.5614 - accuracy: 0.7766
# Epoch 3/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5390 - accuracy: 0.7893
# Epoch 4/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5280 - accuracy: 0.7966
# Epoch 5/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5233 - accuracy: 0.7976
# Epoch 6/18
# 169/169 [==============================] - 3s 19ms/step - loss: 0.5188 - accuracy: 0.7995
# Epoch 7/18
# 169/169 [==============================] - 3s 19ms/step - loss: 0.5152 - accuracy: 0.7998
# Epoch 8/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5127 - accuracy: 0.8006
# Epoch 9/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5104 - accuracy: 0.8016
# Epoch 10/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5083 - accuracy: 0.8017
# Epoch 11/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5081 - accuracy: 0.8015
# Epoch 12/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5066 - accuracy: 0.8023
# Epoch 13/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5058 - accuracy: 0.8016
# Epoch 14/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5051 - accuracy: 0.8015
# Epoch 15/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5048 - accuracy: 0.8017
# Epoch 16/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5038 - accuracy: 0.8017
# Epoch 17/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5027 - accuracy: 0.8021
# Epoch 18/18
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5018 - accuracy: 0.8026

# %%
print(_.best_params_)
print(_.best_score_)
# Out:
# {'batch_size': 2048, 'epochs': 18}
# 0.8095350205795349

# %% [markdown]
# ### Prediction for Submission

# %%
test = pd.read_feather('./output/val_allx_Optmzd_feather')

# %%
null_cols = ['D_17','D_38', 'D_43', 'D_96', 'D_39', 'B_7', 'D_73', 'B_22', 'D_12', 'D_132', 
'D_114', 'D_80', 'D_97', 'R_8', 'B_26', 'D_110', 'R_7', 'D_11', 'D_95', 'D_105', 'D_48', 'D_141', 
'D_142', 'D_10', 'D_68', 'D_92', 'D_31', 'D_106', 'B_29', 'D_133', 'S_23', 'D_89', 'S_19', 'D_8', 'S_25', 'S_7', 'D_64', 'D_40', 'D_22']

# test.drop(null_cols,axis=1,inplace=True)


test_encoded = pd.get_dummies(test,columns=cat_columns,drop_first=True)

# %%
test_encoded = test_encoded.astype({col: 'uint8' for col in test_encoded.select_dtypes('category').columns})

# %%
# for col in test_encoded.columns:
    # test_encoded[col].fillna(100)

# %%
# norm_test_data = test_encoded.copy()
scaler = StandardScaler()

std_val_data = scaler.fit_transform(test_encoded.drop('ID',axis=1))
std_val_data = pd.DataFrame(std_val_data).fillna(1000)

# %%
rf_preds = rf.predict(std_val_data)
rfPred = pd.DataFrame(test_encoded['ID'])
rfPred['Label'] = rf_preds

# %%
ee_preds = ee.predict(std_val_data)
eePred = pd.DataFrame(test_encoded['ID'])
eePred['Label'] = ee_preds

# %%
# valx_pred = rf.predict(test_encoded.drop('ID',axis=1))
xgp_preds = xgb.predict(std_val_data) 
xgbPred = pd.DataFrame(test_encoded['ID'])
xgbPred['Label'] = xgp_preds

# %%
rfPred['Label'].value_counts()
# Out:
# 0    406704
# 2     33522
# 1     25926
# 3      1814
# Name: Label, dtype: int64

# %%
eePred['Label'].value_counts()
# Out:
# 0    360282
# 2     39797
# 1     37692
# 3     30195
# Name: Label, dtype: int64

# %%
xgbPred['Label'].value_counts()
# Out:
# 0    353441
# 2     48433
# 1     42804
# 3     23288
# Name: Label, dtype: int64

# %%
rfPred.to_csv('./output/class_0.csv',index=False)
eePred.to_csv('./output/class_1_3.csv',index=False)
xgbPred.to_csv('./output/class_2.csv',index=False)

# %%
fullPred =  rfPred.join(eePred['Label'],rsuffix="1&3").join(xgbPred['Label'],rsuffix="2")
fullPred.to_csv('./output/Full-Class.csv',index=False)
fullPred.head(10)
# Out:
#            ID  Label  Label1&3  Label2
# 0  3337446730      0         0       0
# 1  7888784125      0         0       0
# 2  9871378905      1         2       2
# 3  8891869609      0         0       0
# 4  2006443827      0         0       0
# 5  7340888752      0         0       0
# 6  1646892613      0         0       0
# 7  3726705791      0         0       0
# 8  7542013488      0         0       0
# 9  4183652505      0         0       2

# %%
class_2 = fullPred[fullPred['Label2']==2][['ID','Label2']]

# %%
# class_1_3 = 
fullPred[fullPred['Label1&3']==1][['ID','Label1&3']] #.merge(fullPred[fullPred['Label1&3']==3][['ID','Label1&3']])
# Out:
#                 ID  Label1&3
# 10      1275012945         1
# 19      6226919132         1
# 23      9178484336         1
# 49      5117410894         1
# 50      6917559729         1
# ...            ...       ...
# 467912  9644730765         1
# 467927  1388125088         1
# 467946  6285658361         1
# 467961  5512100313         1
# 467963  4896427435         1
#
# [37692 rows x 2 columns]

# %%
finalPreds = pd.read_csv('./output/mode.csv')
finalPreds.head()
# Out:
#            ID  Label  Label1&3  Label2  Final  Unnamed: 5  Mode++
# 0  3337446730      0         0       0      0         0.0       0
# 1  7888784125      0         0       0      0         0.0       0
# 2  9871378905      1         2       2      2         2.0       2
# 3  8891869609      0         0       0      0         0.0       0
# 4  2006443827      0         0       0      0         0.0       0

# %%
finalPreds['Mode++'].value_counts()
# Out:
# 0    371964
# 2     37023
# 1     35852
# 3     23127
# Name: Mode++, dtype: int64

# %%
finalfinal = finalPreds[['ID','Mode++']]
finalfinal
# Out:
#                 ID  Mode++
# 0       3337446730       0
# 1       7888784125       0
# 2       9871378905       2
# 3       8891869609       0
# 4       2006443827       0
# ...            ...     ...
# 467961  5512100313       1
# 467962  2488191588       0
# 467963  4896427435       2
# 467964  9244915426       0
# 467965  4727936004       0
#
# [467966 rows x 2 columns]

# %%
finalfinal.to_csv('./output/FINAL_FINAL_FINAL_Buahaha.csv',index=False)
